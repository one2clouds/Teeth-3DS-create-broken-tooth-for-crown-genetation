# %%
import json 
import numpy as np 
import open3d as o3d
from extract_context_teeth import extract_teeth_group_and_their_gums, mesh_to_pcd
import os 
from glob import glob
import re
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
def extract_segments_from_json(json_file_path):
    with open(json_file_path, 'r') as f:
        data = json.load(f)
    segments = []
    for cell in data['cells']:
        segments.append(cell['fdi'])
    segments = np.array(segments)
    try:
        abutment_teeth = data["abutment_teeth"]
    except KeyError:
        abutment_teeth = None
        print(f"Warning: No 'abutment_teeth' key in {json_file_path}")

    return segments, abutment_teeth

# %%
ply_names = sorted(glob("/home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/CROWN-PARTIAL-ANNOTATED-TOOTH/ply/*.ply"))
json_names = sorted(glob("/home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/CROWN-PARTIAL-ANNOTATED-TOOTH/json/*.json"))

elements = []
for ply_name, json_name in zip(ply_names, json_names):
    # print(ply_name)
    # print(json_name)

    match = re.search(r"CROWN-PARTIAL-([0-9]{4}-[0-9]{2}-[0-9]{2}_[0-9]{5}-\d{3}_[0-9]{4}-[0-9]{2}-[0-9]{2}_[0-9]{5}-\d{3})",json_name).group(1)
    
    # print(match)

    segment, abutment_teeth = extract_segments_from_json(json_name)
    if abutment_teeth:
        # print(json_name)
        # print(abutment_teeth)
        # print("-"*80)
        elements.append(abutment_teeth[0])

# %%
# elements

# %%
set(elements)
# Out:
# {36, 46}

# %%
# Why instead of just one neighbor, we try to keep instances for two neighbors, it is because for example we want to extract left neighbor of tooth 36(molar), it is 35(premolar) but in edge case some people wouldn't have two premolar, and only one premolar(34 or 35)
# In such case we take backup teeth 35 which is its nearest left neighbor 

abut_context_teeth_dict_ = {
    "abutment_teeth":["Left_Neighbor", "Abutment Teeth" ,"Right_Neighbor", "Left_Antagonist", "Middle_Antagonist", "Right_Antagonist"],
    32: [[31,41], [32], [33,34], [21,11], [22], [23,24]], 
    35: [[34,33], [35], [36,37], [24,23], [25], [26,27]],
    36: [[35,34], [36], [37,38], [25,24], [26], [27,28]],
    37: [[36,35], [37], [38], [26,25], [27], [28]],

    44: [[45,46], [44], [43,42], [15,16], [14], [13,12]],
    46: [[47,48], [46], [45,44], [17, 18], [16], [15, 14]],
    47: [[48], [47], [46,45], [18], [17], [16,15]],
}

# %%
def extract_highest_priority(tooth_number, available_teeth, abut_dict):
    result = []
    for group in abut_dict[tooth_number]:
        selected = None
        for candidate in group:
            if candidate in available_teeth:
                selected = candidate
                break  # stop at the first match (highest priority)
        if selected is not None:
            result.append(selected)
    return result

# %%
# available_teeth = np.unique(segment)

# target_segment_ids = extract_highest_priority(abutment_teeth[0], available_teeth, abut_context_teeth_dict_)
# target_segment_ids

# %%
ply_names = sorted(glob("/home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/CROWN-PARTIAL-ANNOTATED-TOOTH/ply/*.ply"))
json_names = sorted(glob("/home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/CROWN-PARTIAL-ANNOTATED-TOOTH/json/*.json"))

elements = []
for ply_name, json_name in zip(ply_names, json_names):
    # print(ply_name)
    # print(json_name)
    segment_only_abutment, abutment_teeth = extract_segments_from_json(json_name)
    if abutment_teeth:
        # print(json_name)
        # print(abutment_teeth)
        # print("-"*80)
        # elements.append(abutment_teeth[0])

        # print(abut_context_teeth_dict_[abutment_teeth[0]])

        label = "master"
        mesh = o3d.io.read_triangle_mesh(ply_name)

        available_teeth = np.unique(segment_only_abutment) # A SET OF AVAILABLE LABELS WHICH WE HAVE TO CHOOSE FROM 
        target_segment_ids = extract_highest_priority(abutment_teeth[0], available_teeth, abut_context_teeth_dict_)

        # print(available_teeth)
        # print(target_segment_ids)

        abutment_mesh, _, _ = extract_teeth_group_and_their_gums(mesh, segment_only_abutment, target_segment_ids)
        pcd_abutment_mesh, npy_abutment_mesh = mesh_to_pcd(abutment_mesh, num_points=1000)

        unique_customer_id = re.search(r"CROWN-PARTIAL-([0-9]{4}-[0-9]{2}-[0-9]{2}_[0-9]{5}-\d{3}_[0-9]{4}-[0-9]{2}-[0-9]{2}_[0-9]{5}-\d{3})", os.path.basename(json_name)).group(1)
        
        if abutment_teeth[0] in [11,12,13,14,15,16,17,18,21,22,23,24,25,26,27,28]: # UPPER JAW 
            new_MASTER_ply_name = os.path.join(os.path.dirname(ply_name), "CROWN-PARTIAL-" + unique_customer_id + "-upperjaw.ply")
            new_MASTER_json_name = os.path.join(os.path.dirname(json_name), "CROWN-PARTIAL-" + unique_customer_id + "-upperjaw.json")

            new_ANTAGONIST_ply_name = os.path.join(os.path.dirname(ply_name), "CROWN-PARTIAL-" + unique_customer_id + "-lowerjaw.ply")
            new_ANTAGONIST_json_name = os.path.join(os.path.dirname(json_name), "CROWN-PARTIAL-" + unique_customer_id + "-lowerjaw.json")

        
        elif abutment_teeth[0] in [31,32,33,34,35,36,37,38,41,42,43,44,45,46,47,48]: #LOWER JAW 

            new_MASTER_ply_name = os.path.join(os.path.dirname(ply_name), "CROWN-PARTIAL-" + unique_customer_id + "-lowerjaw.ply")
            new_MASTER_json_name = os.path.join(os.path.dirname(json_name), "CROWN-PARTIAL-" + unique_customer_id + "-lowerjaw.json")

            new_ANTAGONIST_ply_name = os.path.join(os.path.dirname(ply_name), "CROWN-PARTIAL-" + unique_customer_id + "-upperjaw.ply")
            new_ANTAGONIST_json_name = os.path.join(os.path.dirname(json_name), "CROWN-PARTIAL-" + unique_customer_id + "-upperjaw.json")

        # print(new_MASTER_ply_name)
        # print(new_ANTAGONIST_ply_name)
        
        segment, _ = extract_segments_from_json(new_MASTER_json_name)
        mesh = o3d.io.read_triangle_mesh(new_MASTER_ply_name)

        available_teeth = np.unique(segment) # A SET OF AVAILABLE LABELS WHICH WE HAVE TO CHOOSE FROM 
        target_segment_ids = extract_highest_priority(abutment_teeth[0], available_teeth, abut_context_teeth_dict_)

        MASTER_mesh, _, _ = extract_teeth_group_and_their_gums(mesh, segment, target_segment_ids)
        pcd_master_mesh, npy_master_mesh = mesh_to_pcd(MASTER_mesh, num_points=3096)


        #COMBINE ABUTMENT TOOTH PCD MESH AND MASTER MESH
        combined_pcd_MASTER_mesh = pcd_abutment_mesh + pcd_master_mesh

        os.makedirs(f"outputs-CROWN-PARTIAL-ANNOTATED/{unique_customer_id}", exist_ok=True)
        o3d.io.write_point_cloud(os.path.join(f"outputs-CROWN-PARTIAL-ANNOTATED/{unique_customer_id}", f"{unique_customer_id}_{label}.pcd"), combined_pcd_MASTER_mesh)
        print(os.path.join(f"outputs-CROWN-PARTIAL-ANNOTATED/{unique_customer_id}", f"{unique_customer_id}_{label}.pcd"))


        # FOR OPPOSITE JAW  
        segment, _ = extract_segments_from_json(new_ANTAGONIST_json_name)
        label = "Antagonist"
        mesh = o3d.io.read_triangle_mesh(new_ANTAGONIST_ply_name)

        available_teeth = np.unique(segment) # A SET OF AVAILABLE LABELS WHICH WE HAVE TO CHOOSE FROM 
        target_segment_ids = extract_highest_priority(abutment_teeth[0], available_teeth, abut_context_teeth_dict_)

        ANTAGONIST_mesh, _, _ = extract_teeth_group_and_their_gums(mesh, segment, target_segment_ids)
        pcd_antagonist_mesh, npy_antagonist_mesh = mesh_to_pcd(ANTAGONIST_mesh, num_points=4096)

        o3d.io.write_point_cloud(os.path.join(f"outputs-CROWN-PARTIAL-ANNOTATED/{unique_customer_id}", f"{unique_customer_id}_{label}.pcd"), pcd_antagonist_mesh)
        print(os.path.join(f"outputs-CROWN-PARTIAL-ANNOTATED/{unique_customer_id}", f"{unique_customer_id}_{label}.pcd"))
    else:
        continue
# Out:
# Original mesh: 37012 vertices, 73522 triangles
# Found 1 connected components
# Component sizes (triangles): [73522]
# Keeping 1 components with >= 5290 triangles
# Cleaned mesh: 37012 vertices, 73522 triangles
# Original mesh: 24902 vertices, 48975 triangles
# Found 2 connected components
# Component sizes (triangles): [33008 15967]
# Keeping 2 components with >= 5290 triangles
# Cleaned mesh: 24902 vertices, 48975 triangles
# outputs-CROWN-PARTIAL-ANNOTATED/2018-10-16_00001-021_2018-10-16_00001-021/2018-10-16_00001-021_2018-10-16_00001-021_master.pcd
# Original mesh: 28269 vertices, 55678 triangles
# Found 1 connected components
# Component sizes (triangles): [55678]
# Keeping 1 components with >= 5290 triangles
# Cleaned mesh: 28269 vertices, 55678 triangles
# outputs-CROWN-PARTIAL-ANNOTATED/2018-10-16_00001-021_2018-10-16_00001-021/2018-10-16_00001-021_2018-10-16_00001-021_Antagonist.pcd
# Original mesh: 42300 vertices, 84009 triangles
# Found 1 connected components
# Component sizes (triangles): [84009]
# Keeping 1 components with >= 5290 triangles
# Cleaned mesh: 42300 vertices, 84009 triangles
# Original mesh: 28371 vertices, 55412 triangles
# Found 3 connected components
# Component sizes (triangles): [33300   937 21175]
# Keeping 2 components with >= 5290 triangles
# Cleaned mesh: 27846 vertices, 54475 triangles
# outputs-CROWN-PARTIAL-ANNOTATED/2018-10-16_00001-022_2018-10-16_00001-022/2018-10-16_00001-022_2018-10-16_00001-022_master.pcd
# Original mesh: 39954 vertices, 78765 triangles
# Found 1 connected components
# Component sizes (triangles): [78765]
# Keeping 1 components with >= 5290 triangles
# Cleaned mesh: 39954 vertices, 78765 triangles
# outputs-CROWN-PARTIAL-ANNOTATED/2018-10-16_00001-022_2018-10-16_00001-022/2018-10-16_00001-022_2018-10-16_00001-022_Antagonist.pcd
# Original mesh: 42658 vertices, 84763 triangles
# Found 1 connected components
# Component sizes (triangles): [84763]
# Keeping 1 components with >= 5290 triangles
# Cleaned mesh: 42658 vertices, 84763 triangles
# Original mesh: 24017 vertices, 47165 triangles
# Found 2 connected components
# Component sizes (triangles): [29433 17732]
# Keeping 2 components with >= 5290 triangles
# Cleaned mesh: 24017 vertices, 47165 triangles
# outputs-CROWN-PARTIAL-ANNOTATED/2018-10-16_00001-023_2018-10-16_00001-023/2018-10-16_00001-023_2018-10-16_00001-023_master.pcd
# Original mesh: 37898 vertices, 74915 triangles
# Found 1 connected components
# Component sizes (triangles): [74915]
# Keeping 1 components with >= 5290 triangles
# Cleaned mesh: 37898 vertices, 74915 triangles
# outputs-CROWN-PARTIAL-ANNOTATED/2018-10-16_00001-023_2018-10-16_00001-023/2018-10-16_00001-023_2018-10-16_00001-023_Antagonist.pcd
# Original mesh: 39603 vertices, 78579 triangles
# Found 1 connected components
# Component sizes (triangles): [78579]
# Keeping 1 components with >= 5290 triangles
# Cleaned mesh: 39603 vertices, 78579 triangles
# Original mesh: 31828 vertices, 62633 triangles
# Found 2 connected components
# Component sizes (triangles): [37378 25255]
# Keeping 2 components with >= 5290 triangles
# Cleaned mesh: 31828 vertices, 62633 triangles
# outputs-CROWN-PARTIAL-ANNOTATED/2018-10-16_00001-024_2018-10-16_00001-024/2018-10-16_00001-024_2018-10-16_00001-024_master.pcd
# Original mesh: 39905 vertices, 78584 triangles
# Found 1 connected components
# Component sizes (triangles): [78584]
# Keeping 1 components with >= 5290 triangles
# Cleaned mesh: 39905 vertices, 78584 triangles
# outputs-CROWN-PARTIAL-ANNOTATED/2018-10-16_00001-024_2018-10-16_00001-024/2018-10-16_00001-024_2018-10-16_00001-024_Antagonist.pcd
# Original mesh: 26159 vertices, 51764 triangles
# Found 1 connected components
# Component sizes (triangles): [51764]
# Keeping 1 components with >= 5290 triangles
# Cleaned mesh: 26159 vertices, 51764 triangles
# Original mesh: 30067 vertices, 59240 triangles
# Found 2 connected components
# Component sizes (triangles): [41554 17686]
# Keeping 2 components with >= 5290 triangles
# Cleaned mesh: 30067 vertices, 59240 triangles
# outputs-CROWN-PARTIAL-ANNOTATED/2018-10-16_00002-019_2018-10-16_00002-019/2018-10-16_00002-019_2018-10-16_00002-019_master.pcd
# Original mesh: 31049 vertices, 61348 triangles
# Found 1 connected components
# Component sizes (triangles): [61348]
# Keeping 1 components with >= 5290 triangles
# Cleaned mesh: 31049 vertices, 61348 triangles
# outputs-CROWN-PARTIAL-ANNOTATED/2018-10-16_00002-019_2018-10-16_00002-019/2018-10-16_00002-019_2018-10-16_00002-019_Antagonist.pcd
# Original mesh: 34535 vertices, 68506 triangles
# Found 1 connected components
# Component sizes (triangles): [68506]
# Keeping 1 components with >= 5290 triangles
# Cleaned mesh: 34535 vertices, 68506 triangles
# Original mesh: 20512 vertices, 40243 triangles
# Found 2 connected components
# Component sizes (triangles): [22949 17294]
# Keeping 2 components with >= 5290 triangles
# Cleaned mesh: 20512 vertices, 40243 triangles
# outputs-CROWN-PARTIAL-ANNOTATED/2018-10-16_00002-020_2018-10-16_00002-020/2018-10-16_00002-020_2018-10-16_00002-020_master.pcd
# Original mesh: 33329 vertices, 65610 triangles
# Found 1 connected components
# Component sizes (triangles): [65610]
# Keeping 1 components with >= 5290 triangles
# Cleaned mesh: 33329 vertices, 65610 triangles
# outputs-CROWN-PARTIAL-ANNOTATED/2018-10-16_00002-020_2018-10-16_00002-020/2018-10-16_00002-020_2018-10-16_00002-020_Antagonist.pcd
# Original mesh: 29866 vertices, 59268 triangles
# Found 1 connected components
# Component sizes (triangles): [59268]
# Keeping 1 components with >= 5290 triangles
# Cleaned mesh: 29866 vertices, 59268 triangles
# Original mesh: 22780 vertices, 44905 triangles
# Found 2 connected components
# Component sizes (triangles): [30689 14216]
# Keeping 2 components with >= 5290 triangles
# Cleaned mesh: 22780 vertices, 44905 triangles
# outputs-CROWN-PARTIAL-ANNOTATED/2018-10-18_00001-018_2018-10-18_00001-018/2018-10-18_00001-018_2018-10-18_00001-018_master.pcd
# Original mesh: 30042 vertices, 59313 triangles
# Found 1 connected components
# Component sizes (triangles): [59313]
# Keeping 1 components with >= 5290 triangles
# Cleaned mesh: 30042 vertices, 59313 triangles
# outputs-CROWN-PARTIAL-ANNOTATED/2018-10-18_00001-018_2018-10-18_00001-018/2018-10-18_00001-018_2018-10-18_00001-018_Antagonist.pcd
# Original mesh: 33193 vertices, 65892 triangles
# Found 1 connected components
# Component sizes (triangles): [65892]
# Keeping 1 components with >= 5290 triangles
# Cleaned mesh: 33193 vertices, 65892 triangles
# Original mesh: 19156 vertices, 37668 triangles
# Found 2 connected components
# Component sizes (triangles): [23732 13936]
# Keeping 2 components with >= 5290 triangles
# Cleaned mesh: 19156 vertices, 37668 triangles
# outputs-CROWN-PARTIAL-ANNOTATED/2018-10-19_00002-015_2018-10-19_00002-015/2018-10-19_00002-015_2018-10-19_00002-015_master.pcd
# Original mesh: 30376 vertices, 59997 triangles
# Found 1 connected components
# Component sizes (triangles): [59997]
# Keeping 1 components with >= 5290 triangles
# Cleaned mesh: 30376 vertices, 59997 triangles
# outputs-CROWN-PARTIAL-ANNOTATED/2018-10-19_00002-015_2018-10-19_00002-015/2018-10-19_00002-015_2018-10-19_00002-015_Antagonist.pcd
# Original mesh: 30502 vertices, 60474 triangles
# Found 1 connected components
# Component sizes (triangles): [60474]
# Keeping 1 components with >= 5290 triangles
# Cleaned mesh: 30502 vertices, 60474 triangles
# Original mesh: 18407 vertices, 36066 triangles
# Found 2 connected components
# Component sizes (triangles): [18051 18015]
# Keeping 2 components with >= 5290 triangles
# Cleaned mesh: 18407 vertices, 36066 triangles
# outputs-CROWN-PARTIAL-ANNOTATED/2018-10-19_00002-016_2018-10-19_00002-016/2018-10-19_00002-016_2018-10-19_00002-016_master.pcd
# Original mesh: 33981 vertices, 66758 triangles
# Found 2 connected components
# Component sizes (triangles): [64394  2364]
# Keeping 1 components with >= 5290 triangles
# Cleaned mesh: 32713 vertices, 64394 triangles
# outputs-CROWN-PARTIAL-ANNOTATED/2018-10-19_00002-016_2018-10-19_00002-016/2018-10-19_00002-016_2018-10-19_00002-016_Antagonist.pcd
# Original mesh: 26108 vertices, 51780 triangles
# Found 1 connected components
# Component sizes (triangles): [51780]
# Keeping 1 components with >= 5290 triangles
# Cleaned mesh: 26108 vertices, 51780 triangles
# Original mesh: 20415 vertices, 39947 triangles
# Found 3 connected components
# Component sizes (triangles): [25184 12874  1889]
# Keeping 2 components with >= 5290 triangles
# Cleaned mesh: 19391 vertices, 38058 triangles
# outputs-CROWN-PARTIAL-ANNOTATED/2018-10-20_00001-017_2018-10-20_00001-017/2018-10-20_00001-017_2018-10-20_00001-017_master.pcd
# Original mesh: 25925 vertices, 50482 triangles
# Found 2 connected components
# Component sizes (triangles): [37251 13231]
# Keeping 2 components with >= 5290 triangles
# Cleaned mesh: 25925 vertices, 50482 triangles
# outputs-CROWN-PARTIAL-ANNOTATED/2018-10-20_00001-017_2018-10-20_00001-017/2018-10-20_00001-017_2018-10-20_00001-017_Antagonist.pcd
# Original mesh: 29000 vertices, 57469 triangles
# Found 1 connected components
# Component sizes (triangles): [57469]
# Keeping 1 components with >= 5290 triangles
# Cleaned mesh: 29000 vertices, 57469 triangles
# Original mesh: 21771 vertices, 42908 triangles
# Found 2 connected components
# Component sizes (triangles): [27700 15208]
# Keeping 2 components with >= 5290 triangles
# Cleaned mesh: 21771 vertices, 42908 triangles
# outputs-CROWN-PARTIAL-ANNOTATED/2018-10-22_00001-016_2018-10-22_00001-016/2018-10-22_00001-016_2018-10-22_00001-016_master.pcd
# Original mesh: 28152 vertices, 55537 triangles
# Found 1 connected components
# Component sizes (triangles): [55537]
# Keeping 1 components with >= 5290 triangles
# Cleaned mesh: 28152 vertices, 55537 triangles
# outputs-CROWN-PARTIAL-ANNOTATED/2018-10-22_00001-016_2018-10-22_00001-016/2018-10-22_00001-016_2018-10-22_00001-016_Antagonist.pcd
# Original mesh: 41177 vertices, 81820 triangles
# Found 1 connected components
# Component sizes (triangles): [81820]
# Keeping 1 components with >= 5290 triangles
# Cleaned mesh: 41177 vertices, 81820 triangles
# Original mesh: 26585 vertices, 52353 triangles
# Found 2 connected components
# Component sizes (triangles): [38587 13766]
# Keeping 2 components with >= 5290 triangles
# Cleaned mesh: 26585 vertices, 52353 triangles
# outputs-CROWN-PARTIAL-ANNOTATED/2018-10-23_00001-001_2018-10-23_00001-001/2018-10-23_00001-001_2018-10-23_00001-001_master.pcd
# Original mesh: 40793 vertices, 79988 triangles
# Found 2 connected components
# Component sizes (triangles): [78321  1667]
# Keeping 1 components with >= 5290 triangles
# Cleaned mesh: 39874 vertices, 78321 triangles
# outputs-CROWN-PARTIAL-ANNOTATED/2018-10-23_00001-001_2018-10-23_00001-001/2018-10-23_00001-001_2018-10-23_00001-001_Antagonist.pcd
# Original mesh: 31990 vertices, 63488 triangles
# Found 1 connected components
# Component sizes (triangles): [63488]
# Keeping 1 components with >= 5290 triangles
# Cleaned mesh: 31990 vertices, 63488 triangles
# Original mesh: 20629 vertices, 40459 triangles
# Found 2 connected components
# Component sizes (triangles): [26754 13705]
# Keeping 2 components with >= 5290 triangles
# Cleaned mesh: 20629 vertices, 40459 triangles
# outputs-CROWN-PARTIAL-ANNOTATED/2018-10-23_00001-023_2018-10-23_00001-023/2018-10-23_00001-023_2018-10-23_00001-023_master.pcd
# Original mesh: 34981 vertices, 69136 triangles
# Found 1 connected components
# Component sizes (triangles): [69136]
# Keeping 1 components with >= 5290 triangles
# Cleaned mesh: 34981 vertices, 69136 triangles
# outputs-CROWN-PARTIAL-ANNOTATED/2018-10-23_00001-023_2018-10-23_00001-023/2018-10-23_00001-023_2018-10-23_00001-023_Antagonist.pcd
# Original mesh: 23885 vertices, 47259 triangles
# Found 1 connected components
# Component sizes (triangles): [47259]
# Keeping 1 components with >= 5290 triangles
# Cleaned mesh: 23885 vertices, 47259 triangles
# Original mesh: 29075 vertices, 57250 triangles
# Found 2 connected components
# Component sizes (triangles): [40458 16792]
# Keeping 2 components with >= 5290 triangles
# Cleaned mesh: 29075 vertices, 57250 triangles
# outputs-CROWN-PARTIAL-ANNOTATED/2018-10-24_00001-020_2018-10-24_00001-020/2018-10-24_00001-020_2018-10-24_00001-020_master.pcd
# Original mesh: 34051 vertices, 67186 triangles
# Found 1 connected components
# Component sizes (triangles): [67186]
# Keeping 1 components with >= 5290 triangles
# Cleaned mesh: 34051 vertices, 67186 triangles
# outputs-CROWN-PARTIAL-ANNOTATED/2018-10-24_00001-020_2018-10-24_00001-020/2018-10-24_00001-020_2018-10-24_00001-020_Antagonist.pcd
# Original mesh: 32580 vertices, 64577 triangles
# Found 1 connected components
# Component sizes (triangles): [64577]
# Keeping 1 components with >= 5290 triangles
# Cleaned mesh: 32580 vertices, 64577 triangles
# Original mesh: 23848 vertices, 46953 triangles
# Found 2 connected components
# Component sizes (triangles): [28900 18053]
# Keeping 2 components with >= 5290 triangles
# Cleaned mesh: 23848 vertices, 46953 triangles
# outputs-CROWN-PARTIAL-ANNOTATED/2018-10-29_00001-007_2018-10-29_00001-007/2018-10-29_00001-007_2018-10-29_00001-007_master.pcd
# Original mesh: 44520 vertices, 87642 triangles
# Found 1 connected components
# Component sizes (triangles): [87642]
# Keeping 1 components with >= 5290 triangles
# Cleaned mesh: 44520 vertices, 87642 triangles
# outputs-CROWN-PARTIAL-ANNOTATED/2018-10-29_00001-007_2018-10-29_00001-007/2018-10-29_00001-007_2018-10-29_00001-007_Antagonist.pcd
# Original mesh: 32494 vertices, 64479 triangles
# Found 1 connected components
# Component sizes (triangles): [64479]
# Keeping 1 components with >= 5290 triangles
# Cleaned mesh: 32494 vertices, 64479 triangles
# Original mesh: 23379 vertices, 45993 triangles
# Found 2 connected components
# Component sizes (triangles): [29959 16034]
# Keeping 2 components with >= 5290 triangles
# Cleaned mesh: 23379 vertices, 45993 triangles
# outputs-CROWN-PARTIAL-ANNOTATED/2018-10-29_00002-025_2018-10-29_00002-025/2018-10-29_00002-025_2018-10-29_00002-025_master.pcd
# Original mesh: 30237 vertices, 59643 triangles
# Found 1 connected components
# Component sizes (triangles): [59643]
# Keeping 1 components with >= 5290 triangles
# Cleaned mesh: 30237 vertices, 59643 triangles
# outputs-CROWN-PARTIAL-ANNOTATED/2018-10-29_00002-025_2018-10-29_00002-025/2018-10-29_00002-025_2018-10-29_00002-025_Antagonist.pcd
# Original mesh: 42614 vertices, 84705 triangles
# Found 1 connected components
# Component sizes (triangles): [84705]
# Keeping 1 components with >= 5290 triangles
# Cleaned mesh: 42614 vertices, 84705 triangles
# Original mesh: 31018 vertices, 61096 triangles
# Found 2 connected components
# Component sizes (triangles): [41102 19994]
# Keeping 2 components with >= 5290 triangles
# Cleaned mesh: 31018 vertices, 61096 triangles
# outputs-CROWN-PARTIAL-ANNOTATED/2018-11-01_00001-012_2018-11-01_00001-012/2018-11-01_00001-012_2018-11-01_00001-012_master.pcd
# Original mesh: 40211 vertices, 78927 triangles
# Found 1 connected components
# Component sizes (triangles): [78927]
# Keeping 1 components with >= 5290 triangles
# Cleaned mesh: 40211 vertices, 78927 triangles
# outputs-CROWN-PARTIAL-ANNOTATED/2018-11-01_00001-012_2018-11-01_00001-012/2018-11-01_00001-012_2018-11-01_00001-012_Antagonist.pcd
# Original mesh: 28332 vertices, 56140 triangles
# Found 1 connected components
# Component sizes (triangles): [56140]
# Keeping 1 components with >= 5290 triangles
# Cleaned mesh: 28332 vertices, 56140 triangles
# Original mesh: 27876 vertices, 54912 triangles
# Found 2 connected components
# Component sizes (triangles): [37746 17166]
# Keeping 2 components with >= 5290 triangles
# Cleaned mesh: 27876 vertices, 54912 triangles
# outputs-CROWN-PARTIAL-ANNOTATED/2018-11-01_00001-013_2018-11-01_00001-013/2018-11-01_00001-013_2018-11-01_00001-013_master.pcd
# Original mesh: 34975 vertices, 68720 triangles
# Found 1 connected components
# Component sizes (triangles): [68720]
# Keeping 1 components with >= 5290 triangles
# Cleaned mesh: 34975 vertices, 68720 triangles
# outputs-CROWN-PARTIAL-ANNOTATED/2018-11-01_00001-013_2018-11-01_00001-013/2018-11-01_00001-013_2018-11-01_00001-013_Antagonist.pcd
# Original mesh: 42064 vertices, 83508 triangles
# Found 1 connected components
# Component sizes (triangles): [83508]
# Keeping 1 components with >= 5290 triangles
# Cleaned mesh: 42064 vertices, 83508 triangles
# Original mesh: 29472 vertices, 58076 triangles
# Found 2 connected components
# Component sizes (triangles): [37963 20113]
# Keeping 2 components with >= 5290 triangles
# Cleaned mesh: 29472 vertices, 58076 triangles
# outputs-CROWN-PARTIAL-ANNOTATED/2018-11-02_00001-017_2018-11-02_00001-017/2018-11-02_00001-017_2018-11-02_00001-017_master.pcd
# Original mesh: 26075 vertices, 51572 triangles
# Found 1 connected components
# Component sizes (triangles): [51572]
# Keeping 1 components with >= 5290 triangles
# Cleaned mesh: 26075 vertices, 51572 triangles
# outputs-CROWN-PARTIAL-ANNOTATED/2018-11-02_00001-017_2018-11-02_00001-017/2018-11-02_00001-017_2018-11-02_00001-017_Antagonist.pcd
# Original mesh: 27512 vertices, 54479 triangles
# Found 1 connected components
# Component sizes (triangles): [54479]
# Keeping 1 components with >= 5290 triangles
# Cleaned mesh: 27512 vertices, 54479 triangles
# Original mesh: 22264 vertices, 43715 triangles
# Found 2 connected components
# Component sizes (triangles): [28926 14789]
# Keeping 2 components with >= 5290 triangles
# Cleaned mesh: 22264 vertices, 43715 triangles
# outputs-CROWN-PARTIAL-ANNOTATED/2018-11-02_00002-019_2018-11-02_00002-019/2018-11-02_00002-019_2018-11-02_00002-019_master.pcd
# Original mesh: 29780 vertices, 58524 triangles
# Found 2 connected components
# Component sizes (triangles): [58000   524]
# Keeping 1 components with >= 5290 triangles
# Cleaned mesh: 29479 vertices, 58000 triangles
# outputs-CROWN-PARTIAL-ANNOTATED/2018-11-02_00002-019_2018-11-02_00002-019/2018-11-02_00002-019_2018-11-02_00002-019_Antagonist.pcd
# Original mesh: 37655 vertices, 74770 triangles
# Found 1 connected components
# Component sizes (triangles): [74770]
# Keeping 1 components with >= 5290 triangles
# Cleaned mesh: 37655 vertices, 74770 triangles
# Original mesh: 25312 vertices, 49940 triangles
# Found 2 connected components
# Component sizes (triangles): [32876 17064]
# Keeping 2 components with >= 5290 triangles
# Cleaned mesh: 25312 vertices, 49940 triangles
# outputs-CROWN-PARTIAL-ANNOTATED/2018-11-05_00001-002_2018-11-05_00001-002/2018-11-05_00001-002_2018-11-05_00001-002_master.pcd
# Original mesh: 34849 vertices, 68890 triangles
# Found 1 connected components
# Component sizes (triangles): [68890]
# Keeping 1 components with >= 5290 triangles
# Cleaned mesh: 34849 vertices, 68890 triangles
# outputs-CROWN-PARTIAL-ANNOTATED/2018-11-05_00001-002_2018-11-05_00001-002/2018-11-05_00001-002_2018-11-05_00001-002_Antagonist.pcd
# Original mesh: 30892 vertices, 61261 triangles
# Found 1 connected components
# Component sizes (triangles): [61261]
# Keeping 1 components with >= 5290 triangles
# Cleaned mesh: 30892 vertices, 61261 triangles
# Original mesh: 22330 vertices, 43861 triangles
# Found 2 connected components
# Component sizes (triangles): [31113 12748]
# Keeping 2 components with >= 5290 triangles
# Cleaned mesh: 22330 vertices, 43861 triangles
# outputs-CROWN-PARTIAL-ANNOTATED/2018-11-06_00001-008_2018-11-06_00001-008/2018-11-06_00001-008_2018-11-06_00001-008_master.pcd
# Original mesh: 33334 vertices, 65866 triangles
# Found 1 connected components
# Component sizes (triangles): [65866]
# Keeping 1 components with >= 5290 triangles
# Cleaned mesh: 33334 vertices, 65866 triangles
# outputs-CROWN-PARTIAL-ANNOTATED/2018-11-06_00001-008_2018-11-06_00001-008/2018-11-06_00001-008_2018-11-06_00001-008_Antagonist.pcd
# Original mesh: 31649 vertices, 62776 triangles
# Found 1 connected components
# Component sizes (triangles): [62776]
# Keeping 1 components with >= 5290 triangles
# Cleaned mesh: 31649 vertices, 62776 triangles
# Original mesh: 31117 vertices, 61453 triangles
# Found 2 connected components
# Component sizes (triangles): [41167 20286]
# Keeping 2 components with >= 5290 triangles
# Cleaned mesh: 31117 vertices, 61453 triangles
# outputs-CROWN-PARTIAL-ANNOTATED/2018-11-12_00001-009_2018-11-12_00001-009/2018-11-12_00001-009_2018-11-12_00001-009_master.pcd
# Original mesh: 38226 vertices, 75570 triangles
# Found 1 connected components
# Component sizes (triangles): [75570]
# Keeping 1 components with >= 5290 triangles
# Cleaned mesh: 38226 vertices, 75570 triangles
# outputs-CROWN-PARTIAL-ANNOTATED/2018-11-12_00001-009_2018-11-12_00001-009/2018-11-12_00001-009_2018-11-12_00001-009_Antagonist.pcd
# Original mesh: 24003 vertices, 47569 triangles
# Found 1 connected components
# Component sizes (triangles): [47569]
# Keeping 1 components with >= 5290 triangles
# Cleaned mesh: 24003 vertices, 47569 triangles
# Original mesh: 19530 vertices, 38207 triangles
# Found 2 connected components
# Component sizes (triangles): [25404 12803]
# Keeping 2 components with >= 5290 triangles
# Cleaned mesh: 19530 vertices, 38207 triangles
# outputs-CROWN-PARTIAL-ANNOTATED/2018-11-14_00001-026_2018-11-14_00001-026/2018-11-14_00001-026_2018-11-14_00001-026_master.pcd
# Original mesh: 24778 vertices, 48444 triangles
# Found 2 connected components
# Component sizes (triangles): [48178   266]
# Keeping 1 components with >= 5290 triangles
# Cleaned mesh: 24610 vertices, 48178 triangles
# outputs-CROWN-PARTIAL-ANNOTATED/2018-11-14_00001-026_2018-11-14_00001-026/2018-11-14_00001-026_2018-11-14_00001-026_Antagonist.pcd
# Original mesh: 48780 vertices, 96755 triangles
# Found 1 connected components
# Component sizes (triangles): [96755]
# Keeping 1 components with >= 5290 triangles
# Cleaned mesh: 48780 vertices, 96755 triangles
# Original mesh: 26972 vertices, 53136 triangles
# Found 2 connected components
# Component sizes (triangles): [34883 18253]
# Keeping 2 components with >= 5290 triangles
# Cleaned mesh: 26972 vertices, 53136 triangles
# outputs-CROWN-PARTIAL-ANNOTATED/2018-11-15_00001-008_2018-11-15_00001-008/2018-11-15_00001-008_2018-11-15_00001-008_master.pcd
# Original mesh: 36484 vertices, 71936 triangles
# Found 2 connected components
# Component sizes (triangles): [71836   100]
# Keeping 1 components with >= 5290 triangles
# Cleaned mesh: 36421 vertices, 71836 triangles
# outputs-CROWN-PARTIAL-ANNOTATED/2018-11-15_00001-008_2018-11-15_00001-008/2018-11-15_00001-008_2018-11-15_00001-008_Antagonist.pcd
# Original mesh: 42389 vertices, 84106 triangles
# Found 1 connected components
# Component sizes (triangles): [84106]
# Keeping 1 components with >= 5290 triangles
# Cleaned mesh: 42389 vertices, 84106 triangles
# Original mesh: 23918 vertices, 46925 triangles
# Found 2 connected components
# Component sizes (triangles): [28164 18761]
# Keeping 2 components with >= 5290 triangles
# Cleaned mesh: 23918 vertices, 46925 triangles
# outputs-CROWN-PARTIAL-ANNOTATED/2018-11-15_00010-005_2018-11-15_00010-005/2018-11-15_00010-005_2018-11-15_00010-005_master.pcd
# Original mesh: 35247 vertices, 69625 triangles
# Found 1 connected components
# Component sizes (triangles): [69625]
# Keeping 1 components with >= 5290 triangles
# Cleaned mesh: 35247 vertices, 69625 triangles
# outputs-CROWN-PARTIAL-ANNOTATED/2018-11-15_00010-005_2018-11-15_00010-005/2018-11-15_00010-005_2018-11-15_00010-005_Antagonist.pcd
# Original mesh: 39942 vertices, 79351 triangles
# Found 1 connected components
# Component sizes (triangles): [79351]
# Keeping 1 components with >= 5290 triangles
# Cleaned mesh: 39942 vertices, 79351 triangles
# Original mesh: 29335 vertices, 57838 triangles
# Found 2 connected components
# Component sizes (triangles): [38470 19368]
# Keeping 2 components with >= 5290 triangles
# Cleaned mesh: 29335 vertices, 57838 triangles
# outputs-CROWN-PARTIAL-ANNOTATED/2018-11-16_00001-007_2018-11-16_00001-007/2018-11-16_00001-007_2018-11-16_00001-007_master.pcd
# Original mesh: 42066 vertices, 83208 triangles
# Found 1 connected components
# Component sizes (triangles): [83208]
# Keeping 1 components with >= 5290 triangles
# Cleaned mesh: 42066 vertices, 83208 triangles
# outputs-CROWN-PARTIAL-ANNOTATED/2018-11-16_00001-007_2018-11-16_00001-007/2018-11-16_00001-007_2018-11-16_00001-007_Antagonist.pcd
# Original mesh: 41803 vertices, 82965 triangles
# Found 1 connected components
# Component sizes (triangles): [82965]
# Keeping 1 components with >= 5290 triangles
# Cleaned mesh: 41803 vertices, 82965 triangles
# Original mesh: 25747 vertices, 50665 triangles
# Found 2 connected components
# Component sizes (triangles): [36395 14270]
# Keeping 2 components with >= 5290 triangles
# Cleaned mesh: 25747 vertices, 50665 triangles
# outputs-CROWN-PARTIAL-ANNOTATED/2018-11-17_00001-018_2018-11-17_00001-018/2018-11-17_00001-018_2018-11-17_00001-018_master.pcd
# Original mesh: 31173 vertices, 60859 triangles
# Found 2 connected components
# Component sizes (triangles): [54744  6115]
# Keeping 2 components with >= 5290 triangles
# Cleaned mesh: 31173 vertices, 60859 triangles
# outputs-CROWN-PARTIAL-ANNOTATED/2018-11-17_00001-018_2018-11-17_00001-018/2018-11-17_00001-018_2018-11-17_00001-018_Antagonist.pcd
# Original mesh: 39570 vertices, 78505 triangles
# Found 1 connected components
# Component sizes (triangles): [78505]
# Keeping 1 components with >= 5290 triangles
# Cleaned mesh: 39570 vertices, 78505 triangles
# Original mesh: 31519 vertices, 61691 triangles
# Found 2 connected components
# Component sizes (triangles): [44148 17543]
# Keeping 2 components with >= 5290 triangles
# Cleaned mesh: 31519 vertices, 61691 triangles
# outputs-CROWN-PARTIAL-ANNOTATED/2018-11-17_00001-019_2018-11-17_00001-019/2018-11-17_00001-019_2018-11-17_00001-019_master.pcd
# Original mesh: 31094 vertices, 61364 triangles
# Found 1 connected components
# Component sizes (triangles): [61364]
# Keeping 1 components with >= 5290 triangles
# Cleaned mesh: 31094 vertices, 61364 triangles
# outputs-CROWN-PARTIAL-ANNOTATED/2018-11-17_00001-019_2018-11-17_00001-019/2018-11-17_00001-019_2018-11-17_00001-019_Antagonist.pcd
# Original mesh: 46687 vertices, 92792 triangles
# Found 1 connected components
# Component sizes (triangles): [92792]
# Keeping 1 components with >= 5290 triangles
# Cleaned mesh: 46687 vertices, 92792 triangles
# Original mesh: 29514 vertices, 57990 triangles
# Found 2 connected components
# Component sizes (triangles): [38602 19388]
# Keeping 2 components with >= 5290 triangles
# Cleaned mesh: 29514 vertices, 57990 triangles
# outputs-CROWN-PARTIAL-ANNOTATED/2018-11-19_00010-023_2018-11-19_00010-023/2018-11-19_00010-023_2018-11-19_00010-023_master.pcd
# Original mesh: 49630 vertices, 98065 triangles
# Found 1 connected components
# Component sizes (triangles): [98065]
# Keeping 1 components with >= 5290 triangles
# Cleaned mesh: 49630 vertices, 98065 triangles
# outputs-CROWN-PARTIAL-ANNOTATED/2018-11-19_00010-023_2018-11-19_00010-023/2018-11-19_00010-023_2018-11-19_00010-023_Antagonist.pcd
# Original mesh: 31590 vertices, 62642 triangles
# Found 1 connected components
# Component sizes (triangles): [62642]
# Keeping 1 components with >= 5290 triangles
# Cleaned mesh: 31590 vertices, 62642 triangles
# Original mesh: 23238 vertices, 45593 triangles
# Found 2 connected components
# Component sizes (triangles): [30670 14923]
# Keeping 2 components with >= 5290 triangles
# Cleaned mesh: 23238 vertices, 45593 triangles
# outputs-CROWN-PARTIAL-ANNOTATED/2018-11-21_00001-012_2018-11-21_00001-012/2018-11-21_00001-012_2018-11-21_00001-012_master.pcd
# Original mesh: 35274 vertices, 69635 triangles
# Found 1 connected components
# Component sizes (triangles): [69635]
# Keeping 1 components with >= 5290 triangles
# Cleaned mesh: 35274 vertices, 69635 triangles
# outputs-CROWN-PARTIAL-ANNOTATED/2018-11-21_00001-012_2018-11-21_00001-012/2018-11-21_00001-012_2018-11-21_00001-012_Antagonist.pcd
# Original mesh: 34447 vertices, 68417 triangles
# Found 1 connected components
# Component sizes (triangles): [68417]
# Keeping 1 components with >= 5290 triangles
# Cleaned mesh: 34447 vertices, 68417 triangles
# Original mesh: 27064 vertices, 53106 triangles
# Found 2 connected components
# Component sizes (triangles): [36485 16621]
# Keeping 2 components with >= 5290 triangles
# Cleaned mesh: 27064 vertices, 53106 triangles
# outputs-CROWN-PARTIAL-ANNOTATED/2018-11-22_00010-010_2018-11-22_00010-010/2018-11-22_00010-010_2018-11-22_00010-010_master.pcd
# Original mesh: 29248 vertices, 57404 triangles
# Found 2 connected components
# Component sizes (triangles): [55733  1671]
# Keeping 1 components with >= 5290 triangles
# Cleaned mesh: 28337 vertices, 55733 triangles
# outputs-CROWN-PARTIAL-ANNOTATED/2018-11-22_00010-010_2018-11-22_00010-010/2018-11-22_00010-010_2018-11-22_00010-010_Antagonist.pcd
# Original mesh: 35028 vertices, 69284 triangles
# Found 2 connected components
# Component sizes (triangles): [69041   243]
# Keeping 1 components with >= 5290 triangles
# Cleaned mesh: 34877 vertices, 69041 triangles
# Original mesh: 8527 vertices, 16666 triangles
# Found 1 connected components
# Component sizes (triangles): [16666]
# Keeping 1 components with >= 5290 triangles
# Cleaned mesh: 8527 vertices, 16666 triangles
# outputs-CROWN-PARTIAL-ANNOTATED/2018-11-26_00010-008_2018-11-26_00010-008/2018-11-26_00010-008_2018-11-26_00010-008_master.pcd
# Original mesh: 37455 vertices, 73758 triangles
# Found 1 connected components
# Component sizes (triangles): [73758]
# Keeping 1 components with >= 5290 triangles
# Cleaned mesh: 37455 vertices, 73758 triangles
# outputs-CROWN-PARTIAL-ANNOTATED/2018-11-26_00010-008_2018-11-26_00010-008/2018-11-26_00010-008_2018-11-26_00010-008_Antagonist.pcd
# Original mesh: 40099 vertices, 79655 triangles
# Found 1 connected components
# Component sizes (triangles): [79655]
# Keeping 1 components with >= 5290 triangles
# Cleaned mesh: 40099 vertices, 79655 triangles
# Original mesh: 25437 vertices, 50024 triangles
# Found 2 connected components
# Component sizes (triangles): [30323 19701]
# Keeping 2 components with >= 5290 triangles
# Cleaned mesh: 25437 vertices, 50024 triangles
# outputs-CROWN-PARTIAL-ANNOTATED/2018-11-29_00010-003_2018-11-29_00010-003/2018-11-29_00010-003_2018-11-29_00010-003_master.pcd
# Original mesh: 48907 vertices, 96462 triangles
# Found 1 connected components
# Component sizes (triangles): [96462]
# Keeping 1 components with >= 5290 triangles
# Cleaned mesh: 48907 vertices, 96462 triangles
# outputs-CROWN-PARTIAL-ANNOTATED/2018-11-29_00010-003_2018-11-29_00010-003/2018-11-29_00010-003_2018-11-29_00010-003_Antagonist.pcd

# %%
ply_names = sorted(glob("/home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/CROWN-PARTIAL-ANNOTATED-TOOTH/ply/*.ply"))
json_names = sorted(glob("/home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/CROWN-PARTIAL-ANNOTATED-TOOTH/json/*.json"))

elements = []
for ply_name, json_name in zip(ply_names, json_names):
    # print(ply_name)
    # print(json_name)
    segment_only_abutment, abutment_teeth = extract_segments_from_json(json_name)
    if abutment_teeth:
        continue
    else: 
        if "upperjaw" not in os.path.basename(json_name) and "lowerjaw" not in os.path.basename(json_name):
            print(os.path.basename(json_name))
# Out:
# CROWN-PARTIAL-2018-10-24_00001-005_2018-10-24_00001-005-46.json

# %%
# THIS TOOTH IS PROBLAMATIC
# CROWN-PARTIAL-2018-10-24_00001-005_2018-10-24_00001-005-46

# %%
print("hello")
# Out:
# hello

# %% [markdown]
# ### For PCD Extraction of PARTIAL-Crown ONLY

# %%
ply_dir_names = sorted(glob("/home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/outputs-CROWN-PARTIAL-ANNOTATED/*/"))

print(ply_dir_names[0].split('/')[-2])
print(ply_dir_names[0])
# Out:
# 2018-10-16_00001-021_2018-10-16_00001-021
# /home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/outputs-CROWN-PARTIAL-ANNOTATED/2018-10-16_00001-021_2018-10-16_00001-021/

# %%
ply_crown_names = sorted(glob("/home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/Crown-PARTIAL-Only/*/*"))
ply_crown_names
# Out:
# ['/home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/Crown-PARTIAL-Only/2018-10-16_00001-021/2018-10-16_00001-021-36-crown_cad.stl',
#  '/home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/Crown-PARTIAL-Only/2018-10-16_00001-022/2018-10-16_00001-022-36-crown_cad.stl',
#  '/home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/Crown-PARTIAL-Only/2018-10-16_00001-023/2018-10-16_00001-023-36-crown_cad.stl',
#  '/home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/Crown-PARTIAL-Only/2018-10-16_00001-024/2018-10-16_00001-024-36-crown_cad.stl',
#  '/home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/Crown-PARTIAL-Only/2018-10-16_00002-019/2018-10-16_00002-019-36-crown_cad.stl',
#  '/home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/Crown-PARTIAL-Only/2018-10-16_00002-020/2018-10-16_00002-020-36-crown_cad.stl',
#  '/home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/Crown-PARTIAL-Only/2018-10-18_00001-018/2018-10-18_00001-018-36-crown_cad.stl',
#  '/home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/Crown-PARTIAL-Only/2018-10-19_00002-015/2018-10-19_00002-015-36-crown_cad.stl',
#  '/home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/Crown-PARTIAL-Only/2018-10-19_00002-016/2018-10-19_00002-016-36-crown_cad.stl',
#  '/home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/Crown-PARTIAL-Only/2018-10-20_00001-017/2018-10-20_00001-017-36-crown_cad.stl',
#  '/home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/Crown-PARTIAL-Only/2018-10-22_00001-016/2018-10-22_00001-016-36-crown_cad.stl',
#  '/home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/Crown-PARTIAL-Only/2018-10-23_00001-001/2018-10-23_00001-001-36-crown_cad.stl',
#  '/home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/Crown-PARTIAL-Only/2018-10-23_00001-023/2018-10-23_00001-023-36-crown_cad.stl',
#  '/home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/Crown-PARTIAL-Only/2018-10-24_00001-020/2018-10-24_00001-020-36-crown_cad.stl',
#  '/home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/Crown-PARTIAL-Only/2018-10-29_00001-007/2018-10-29_00001-007-36-crown_cad.stl',
#  '/home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/Crown-PARTIAL-Only/2018-10-29_00002-025/2018-10-29_00002-025-36-crown_cad.stl',
#  '/home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/Crown-PARTIAL-Only/2018-11-01_00001-012/2018-11-01_00001-012-46-crown_cad.stl',
#  '/home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/Crown-PARTIAL-Only/2018-11-01_00001-013/2018-11-01_00001-013-36-crown_cad.stl',
#  '/home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/Crown-PARTIAL-Only/2018-11-02_00001-017/2018-11-02_00001-017-36-crown_cad.stl',
#  '/home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/Crown-PARTIAL-Only/2018-11-02_00002-019/2018-11-02_00002-019-36-crown_cad.stl',
#  '/home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/Crown-PARTIAL-Only/2018-11-05_00001-002/2018-11-05_00001-002-36-crown_cad.stl',
#  '/home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/Crown-PARTIAL-Only/2018-11-06_00001-008/2018-11-06_00001-008-36-crown_cad.stl',
#  '/home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/Crown-PARTIAL-Only/2018-11-12_00001-009/2018-11-12_00001-009-36-crown_cad.stl',
#  '/home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/Crown-PARTIAL-Only/2018-11-14_00001-026/2018-11-14_00001-026-36-crown_cad.stl',
#  '/home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/Crown-PARTIAL-Only/2018-11-15_00001-008/2018-11-15_00001-008-36-crown_cad.stl',
#  '/home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/Crown-PARTIAL-Only/2018-11-15_00010-005/2018-11-15_00010-005-36-crown_cad.stl',
#  '/home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/Crown-PARTIAL-Only/2018-11-16_00001-007/2018-11-16_00001-007-46-crown_cad.stl',
#  '/home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/Crown-PARTIAL-Only/2018-11-17_00001-018/2018-11-17_00001-018-36-crown_cad.stl',
#  '/home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/Crown-PARTIAL-Only/2018-11-17_00001-019/2018-11-17_00001-019-36-crown_cad.stl',
#  '/home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/Crown-PARTIAL-Only/2018-11-19_00010-023/2018-11-19_00010-023-36-crown_cad.stl',
#  '/home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/Crown-PARTIAL-Only/2018-11-21_00001-012/2018-11-21_00001-012-36-crown_cad.stl',
#  '/home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/Crown-PARTIAL-Only/2018-11-22_00010-010/2018-11-22_00010-010-36-crown_cad.stl',
#  '/home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/Crown-PARTIAL-Only/2018-11-26_00010-008/2018-11-26_00010-008-36-crown_cad.stl',
#  '/home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/Crown-PARTIAL-Only/2018-11-29_00010-003/2018-11-29_00010-003-36-crown_cad.stl']

# %%
for ply_crown_name in ply_crown_names:
    mesh = o3d.io.read_triangle_mesh(ply_crown_name)
    crown_pcd, crown_npy = mesh_to_pcd(mesh, num_points=1536)
    for ply_dir_name in ply_dir_names: 
        # print(ply_crown_name.split("/")[-2]) 
        # print(ply_dir_name.split('/')[-2])
        if ply_crown_name.split("/")[-2] in ply_dir_name.split('/')[-2]:
            print(os.path.join(ply_dir_name, ply_crown_name.split('/')[-2] + "_shell.pcd"))
            o3d.io.write_point_cloud(os.path.join(ply_dir_name, ply_dir_name.split('/')[-2] + "_shell.pcd"), crown_pcd)
            continue
# Out:
# /home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/outputs-CROWN-PARTIAL-ANNOTATED/2018-10-16_00001-021_2018-10-16_00001-021/2018-10-16_00001-021_shell.pcd
# /home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/outputs-CROWN-PARTIAL-ANNOTATED/2018-10-16_00001-022_2018-10-16_00001-022/2018-10-16_00001-022_shell.pcd
# /home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/outputs-CROWN-PARTIAL-ANNOTATED/2018-10-16_00001-023_2018-10-16_00001-023/2018-10-16_00001-023_shell.pcd
# /home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/outputs-CROWN-PARTIAL-ANNOTATED/2018-10-16_00001-024_2018-10-16_00001-024/2018-10-16_00001-024_shell.pcd
# /home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/outputs-CROWN-PARTIAL-ANNOTATED/2018-10-16_00002-019_2018-10-16_00002-019/2018-10-16_00002-019_shell.pcd
# /home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/outputs-CROWN-PARTIAL-ANNOTATED/2018-10-16_00002-020_2018-10-16_00002-020/2018-10-16_00002-020_shell.pcd
# /home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/outputs-CROWN-PARTIAL-ANNOTATED/2018-10-18_00001-018_2018-10-18_00001-018/2018-10-18_00001-018_shell.pcd
# /home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/outputs-CROWN-PARTIAL-ANNOTATED/2018-10-19_00002-015_2018-10-19_00002-015/2018-10-19_00002-015_shell.pcd
# /home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/outputs-CROWN-PARTIAL-ANNOTATED/2018-10-19_00002-016_2018-10-19_00002-016/2018-10-19_00002-016_shell.pcd
# /home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/outputs-CROWN-PARTIAL-ANNOTATED/2018-10-20_00001-017_2018-10-20_00001-017/2018-10-20_00001-017_shell.pcd
# /home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/outputs-CROWN-PARTIAL-ANNOTATED/2018-10-22_00001-016_2018-10-22_00001-016/2018-10-22_00001-016_shell.pcd
# /home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/outputs-CROWN-PARTIAL-ANNOTATED/2018-10-23_00001-001_2018-10-23_00001-001/2018-10-23_00001-001_shell.pcd
# /home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/outputs-CROWN-PARTIAL-ANNOTATED/2018-10-23_00001-023_2018-10-23_00001-023/2018-10-23_00001-023_shell.pcd
# /home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/outputs-CROWN-PARTIAL-ANNOTATED/2018-10-24_00001-020_2018-10-24_00001-020/2018-10-24_00001-020_shell.pcd
# /home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/outputs-CROWN-PARTIAL-ANNOTATED/2018-10-29_00001-007_2018-10-29_00001-007/2018-10-29_00001-007_shell.pcd
# /home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/outputs-CROWN-PARTIAL-ANNOTATED/2018-10-29_00002-025_2018-10-29_00002-025/2018-10-29_00002-025_shell.pcd
# /home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/outputs-CROWN-PARTIAL-ANNOTATED/2018-11-01_00001-012_2018-11-01_00001-012/2018-11-01_00001-012_shell.pcd
# /home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/outputs-CROWN-PARTIAL-ANNOTATED/2018-11-01_00001-013_2018-11-01_00001-013/2018-11-01_00001-013_shell.pcd
# /home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/outputs-CROWN-PARTIAL-ANNOTATED/2018-11-02_00001-017_2018-11-02_00001-017/2018-11-02_00001-017_shell.pcd
# /home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/outputs-CROWN-PARTIAL-ANNOTATED/2018-11-02_00002-019_2018-11-02_00002-019/2018-11-02_00002-019_shell.pcd
# /home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/outputs-CROWN-PARTIAL-ANNOTATED/2018-11-05_00001-002_2018-11-05_00001-002/2018-11-05_00001-002_shell.pcd
# /home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/outputs-CROWN-PARTIAL-ANNOTATED/2018-11-06_00001-008_2018-11-06_00001-008/2018-11-06_00001-008_shell.pcd
# /home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/outputs-CROWN-PARTIAL-ANNOTATED/2018-11-12_00001-009_2018-11-12_00001-009/2018-11-12_00001-009_shell.pcd
# /home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/outputs-CROWN-PARTIAL-ANNOTATED/2018-11-14_00001-026_2018-11-14_00001-026/2018-11-14_00001-026_shell.pcd
# /home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/outputs-CROWN-PARTIAL-ANNOTATED/2018-11-15_00001-008_2018-11-15_00001-008/2018-11-15_00001-008_shell.pcd
# /home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/outputs-CROWN-PARTIAL-ANNOTATED/2018-11-15_00010-005_2018-11-15_00010-005/2018-11-15_00010-005_shell.pcd
# /home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/outputs-CROWN-PARTIAL-ANNOTATED/2018-11-16_00001-007_2018-11-16_00001-007/2018-11-16_00001-007_shell.pcd
# /home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/outputs-CROWN-PARTIAL-ANNOTATED/2018-11-17_00001-018_2018-11-17_00001-018/2018-11-17_00001-018_shell.pcd
# /home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/outputs-CROWN-PARTIAL-ANNOTATED/2018-11-17_00001-019_2018-11-17_00001-019/2018-11-17_00001-019_shell.pcd
# /home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/outputs-CROWN-PARTIAL-ANNOTATED/2018-11-19_00010-023_2018-11-19_00010-023/2018-11-19_00010-023_shell.pcd
# /home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/outputs-CROWN-PARTIAL-ANNOTATED/2018-11-21_00001-012_2018-11-21_00001-012/2018-11-21_00001-012_shell.pcd
# /home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/outputs-CROWN-PARTIAL-ANNOTATED/2018-11-22_00010-010_2018-11-22_00010-010/2018-11-22_00010-010_shell.pcd
# /home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/outputs-CROWN-PARTIAL-ANNOTATED/2018-11-26_00010-008_2018-11-26_00010-008/2018-11-26_00010-008_shell.pcd
# /home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/outputs-CROWN-PARTIAL-ANNOTATED/2018-11-29_00010-003_2018-11-29_00010-003/2018-11-29_00010-003_shell.pcd

# %%
print("hello")
# Out:
# hello
