# %%
import matplotlib.pyplot as plt 
from mpl_toolkits.mplot3d import Axes3D
import numpy as np 
import open3d as o3d
import plotly.graph_objects as go
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %% [markdown]
# #### ITERO SCAN

# %%
#ITERO SCAN 

antagonist = o3d.io.read_point_cloud("/home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/outputs-CROWN-ITERO-ANNOTATED/20240711_120128_ITERO(168624533)_0/20240711_120128_ITERO(168624533)_0_Antagonist.pcd")
master = o3d.io.read_point_cloud("/home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/outputs-CROWN-ITERO-ANNOTATED/20240711_120128_ITERO(168624533)_0/20240711_120128_ITERO(168624533)_0_master.pcd")

antagonist.colors = o3d.utility.Vector3dVector(np.zeros((len(antagonist.points), 3)))

master.colors = o3d.utility.Vector3dVector(np.zeros((len(master.points), 3)))

print("Point Cloud : Antagonist Scan")
# o3d.visualization.draw_plotly([antagonist])

print("Point Cloud : Master Scan")
# o3d.visualization.draw_plotly([master])
# Out:
# Point Cloud : Antagonist Scan
# Point Cloud : Master Scan

# %% [markdown]
# #### PARTIAL SCAN DATA

# %%
# PARTIAL SCAN 
antagonist = o3d.io.read_point_cloud("/home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/outputs-CROWN-PARTIAL-ANNOTATED/2018-10-20_00001-017_2018-10-20_00001-017/2018-10-20_00001-017_2018-10-20_00001-017_Antagonist.pcd")
master = o3d.io.read_point_cloud("/home/shirshak/Teeth_3DS_data_preparation_for_reconstuction_and_generation/outputs-CROWN-PARTIAL-ANNOTATED/2018-10-20_00001-017_2018-10-20_00001-017/2018-10-20_00001-017_2018-10-20_00001-017_master.pcd")

antagonist.colors = o3d.utility.Vector3dVector(np.zeros((len(antagonist.points), 3)))

master.colors = o3d.utility.Vector3dVector(np.zeros((len(master.points), 3)))

print("Point Cloud : Antagonist Scan")
o3d.visualization.draw_plotly([antagonist])

print("Point Cloud : Master Scan")
o3d.visualization.draw_plotly([master])

# def customize_o3d_plot(point_cloud, title):
#     # Get data bounds
#     points = np.asarray(point_cloud.points)
#     x_min, x_max = points[:, 0].min(), points[:, 0].max()
#     y_min, y_max = points[:, 1].min(), points[:, 1].max()
#     z_min, z_max = points[:, 2].min(), points[:, 2].max()
    
#     # Create custom tick arrays
#     x_ticks = list(range(int(x_min) - 2, int(x_max) + 4, 2))  # increment by 2
#     y_ticks = list(range(int(y_min) - 3, int(y_max) + 6, 3))  # increment by 3  
#     z_ticks = list(range(int(z_min) - 3, int(z_max) + 4, 2))  # increment by 2
    
#     # Use Open3D's draw_plotly - it will show automatically
#     o3d.visualization.draw_plotly([point_cloud], width=1200, height=500)


# # Antagonist visualization
# print("Point Cloud : Antagonist Scan")
# customize_o3d_plot(antagonist, "Antagonist")

# print("\nPoint Cloud : Master Scan")
# customize_o3d_plot(master, "Master")
# Out:
# Point Cloud : Antagonist Scan
# Point Cloud : Master Scan

# %%
input_pcd1 = o3d.io.read_point_cloud("/home/shirshak/DMC/data/data_npy/20240718_131056_ITERO(169483943)_3/20240718_131056_ITERO(169483943) 3_shell.pcd")
input_pcd2 = o3d.io.read_point_cloud("/home/shirshak/DMC/data/data_npy/20240718_131056_ITERO(169483943)_3/20240718_131056_ITERO(169483943)_3_Antagonist.pcd")
input_pcd3 = o3d.io.read_point_cloud("/home/shirshak/DMC/data/data_npy/20240718_131056_ITERO(169483943)_3/20240718_131056_ITERO(169483943)_3_master.pcd")


input_pcd1.translate([-15, 0, 0])

input_pcd2.translate([15, 0, 0])

input_pcd3.translate([10, 0, 0])



input_pcd1.colors = o3d.utility.Vector3dVector(np.zeros((len(input_pcd1.points), 3)))

input_pcd2.colors = o3d.utility.Vector3dVector(np.zeros((len(input_pcd2.points), 3)))

input_pcd3.colors = o3d.utility.Vector3dVector(np.zeros((len(input_pcd3.points), 3)))




print("Point Cloud : Customer's Data Crown   -----> Data : '20240718_131056_ITERO(169483943) 3' ")
# o3d.visualization.draw_plotly([input_pcd1])

print("Point Cloud : Customer's Data Antagonist 'Context Surface' Jaw   -----> Data : '20240718_131056_ITERO(169483943) 3' ")
# o3d.visualization.draw_plotly([input_pcd2])

print("Point Cloud : Customer's Data Master 'Context Surface' Jaw   -----> Data : '20240718_131056_ITERO(169483943) 3' ")
# o3d.visualization.draw_plotly([input_pcd3])
# Out:
# Point Cloud : Customer's Data Crown   -----> Data : '20240718_131056_ITERO(169483943) 3'
# Point Cloud : Customer's Data Antagonist 'Context Surface' Jaw   -----> Data : '20240718_131056_ITERO(169483943) 3'
# Point Cloud : Customer's Data Master 'Context Surface' Jaw   -----> Data : '20240718_131056_ITERO(169483943) 3'

# %%
abut_context_teeth_dict_ = {
    "abutment_teeth":["Left_Neighbor", "Right_Neighbor", "Left_Antagonist", "Middle_Antagonist", "Right_Antagonist"],
    12: [13, 11, 43, 42, 41], 
    16: [17, 15, 47, 46, 45], 
    17: [18, 16, 48, 47, 46],
    35: [34, 36, 24, 25, 26],
    36: [35, 37, 25, 26, 27],
    37: [36, 38, 26, 27, 28],
    46: [47, 45, 17, 16, 15],
    47: [48, 46, 18, 17, 16],
}
